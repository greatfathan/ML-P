# %% [markdown]
# # SHAP (SHapley Additive exPlanations)

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_base = pd.read_csv('../../../data/house-Price.csv', index_col=0)
df_base
# Out:
#                        Price  Bedrooms  Bathrooms  Garage  Build Year  \
# Address
# 1 Datchet Turn        270000         3          2     2.0      2011.0
# 1 McKenzie Corner     470000         4          2     2.0      2005.0
# ...                      ...       ...        ...     ...         ...
# 93 Centennial Avenue  350000         4          2     2.0      2005.0
# 98 Centennial Avenue  441000         4          2     2.0      2004.0
#
#                       Floor Area
# Address
# 1 Datchet Turn               109
# 1 McKenzie Corner            279
# ...                          ...
# 93 Centennial Avenue         177
# 98 Centennial Avenue         195
#
# [204 rows x 6 columns]

# %% [markdown]
# ## Feature selection

# %%
y = df_base['Price']
X = df_base.drop(columns='Price')

# %% [markdown]
# ## Train model

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X, y)
model.score(X, y)
# Out:
# 0.9746449876358452

# %%
pd.DataFrame({
    'y_true': y,
    'y_pred': model.predict(X)
})
# Out:
#                       y_true    y_pred
# Address
# 1 Datchet Turn        270000  270000.0
# 1 McKenzie Corner     470000  470000.0
# ...                      ...       ...
# 93 Centennial Avenue  350000  350000.0
# 98 Centennial Avenue  441000  441000.0
#
# [204 rows x 2 columns]

# %%
df_base
# Out:
#                        Price  Bedrooms  Bathrooms  Garage  Build Year  \
# Address
# 1 Datchet Turn        270000         3          2     2.0      2011.0
# 1 McKenzie Corner     470000         4          2     2.0      2005.0
# ...                      ...       ...        ...     ...         ...
# 93 Centennial Avenue  350000         4          2     2.0      2005.0
# 98 Centennial Avenue  441000         4          2     2.0      2004.0
#
#                       Floor Area
# Address
# 1 Datchet Turn               109
# 1 McKenzie Corner            279
# ...                          ...
# 93 Centennial Avenue         177
# 98 Centennial Avenue         195
#
# [204 rows x 6 columns]

# %% [markdown]
# ## SHAP: Model explainability
#
# How the values of the features affect the prediction of the model.

# %% [markdown]
# ### Explainer

# %%
import shap

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

# %% [markdown]
# ### Explain individual prediction

# %%
shap.initjs()
idx = 0
sample = X.iloc[idx].copy()
shap.force_plot(explainer.expected_value, shap_values[idx], sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iCGB986IFPCWNNPCROGUY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 386672.54901960783, "outValue": 270000.0, "link": "identity", "featureNames": ["Bedrooms", "Bathrooms", "Garage", "Build Year", "Floor Area"], "features": {"0": {"effect": -21126.87187515988, "value": 3.0}, "2": {"effect": 2634.4975952652553, "value": 2.0}, "3": {"effect": -14316.382329594871, "value": 2011.0}, "4": {"effect": -83863.79241011835, "value": 109.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iCGB986IFPCWNNPCROGUY')
#   );
# </script>

# %% [markdown]
# ### Full dataset
#
# #### Decision plot

# %%
shap.decision_plot(explainer.expected_value, shap_values, X)

# %% [markdown]
# #### Force plot

# %%
shap.force_plot(explainer.expected_value, shap_values, X)
# Out:
# <div id='iKXX37D8TPH3XUKG9OWVF'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 386672.54901960783, "link": "identity", "featureNames": ["Bedrooms", "Bathrooms", "Garage", "Build Year", "Floor Area"], "explanations": [{"outValue": 270000.0, "simIndex": 6.0, "features": {"0": {"effect": -21126.87187515988, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 2634.4975952652553, "value": 2.0}, "3": {"effect": -14316.382329594871, "value": 2011.0}, "4": {"effect": -83863.79241011835, "value": 109.0}}}, {"outValue": 470000.0, "simIndex": 39.0, "features": {"0": {"effect": 3420.105164675432, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 538.4860834360127, "value": 2.0}, "3": {"effect": -7003.713432005346, "value": 2005.0}, "4": {"effect": 86372.57316428603, "value": 279.0}}}, {"outValue": 445000.00000000023, "simIndex": 187.0, "features": {"0": {"effect": 3871.6319766806246, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1123.4503443687486, "value": 2.0}, "3": {"effect": 30224.556185115485, "value": 2004.0}, "4": {"effect": 23107.812474227514, "value": 200.0}}}, {"outValue": 410000.0000000002, "simIndex": 196.0, "features": {"0": {"effect": 11107.587284750549, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1504.996168916064, "value": 2.0}, "3": {"effect": 23378.97031428544, "value": 2005.0}, "4": {"effect": -12664.10278755974, "value": 148.0}}}, {"outValue": 245000.00000000006, "simIndex": 13.0, "features": {"0": {"effect": -25200.64373946121, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 3212.2265782164673, "value": 1.0}, "3": {"effect": -18275.038794650034, "value": 2012.0}, "4": {"effect": -101409.093063713, "value": 105.0}}}, {"outValue": 393999.99999999977, "simIndex": 172.0, "features": {"0": {"effect": 3858.755849667319, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -1037.797415033307, "value": 2.0}, "3": {"effect": 2588.0652658914564, "value": 2006.0}, "4": {"effect": 1918.4272798664858, "value": 223.0}}}, {"outValue": 385000.0, "simIndex": 133.0, "features": {"0": {"effect": 9685.354618641672, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -1123.0067304659194, "value": 2.0}, "3": {"effect": 3334.0465718383657, "value": 2007.0}, "4": {"effect": -13568.943479621947, "value": 146.0}}}, {"outValue": 410000.0000000001, "simIndex": 152.0, "features": {"0": {"effect": 3858.755849667319, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1453.5171191978952, "value": 2.0}, "3": {"effect": -7807.837010844085, "value": 2006.0}, "4": {"effect": 25823.015022371157, "value": 183.0}}}, {"outValue": 390000.0000000001, "simIndex": 139.0, "features": {"0": {"effect": 23020.50493248607, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -779.7912776529134, "value": 2.0}, "3": {"effect": 11796.022373063643, "value": 2003.0}, "4": {"effect": -30709.285047504534, "value": 153.0}}}, {"outValue": 419999.9999999999, "simIndex": 155.0, "features": {"0": {"effect": 5553.082913989132, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": 1114.7535445970923, "value": 2.0}, "3": {"effect": 4835.520824699756, "value": 2002.0}, "4": {"effect": 21824.093697106102, "value": 190.0}}}, {"outValue": 160000.00000000012, "simIndex": 32.0, "features": {"0": {"effect": -44326.51465045931, "value": 3.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -31588.805829479108, "value": 3.0}, "3": {"effect": -13487.07305362112, "value": 2011.0}, "4": {"effect": -137270.15548604817, "value": 111.0}}}, {"outValue": 334999.99999999994, "simIndex": 113.0, "features": {"0": {"effect": 3420.105164675432, "value": 4.0}, "1": {"effect": 0.0, "value": 2.0}, "2": {"effect": -2545.646470170219, "value": 2.0}, "3": {"effect": -27022.13169989735, "value": 2005.0}, "4": {"effect": -25524.876014215737, "value": 200.0}}}, {"outValue": 382000.0000000001, "simIndex": 132.0, "features": ...

# %% [markdown]
# #### Summary plot

# %%
shap.summary_plot(shap_values, X, plot_type='bar')

# %% [markdown]
# ## Export artifacts
#
# ### SHAP explainer

# %%
import pickle

with open('../artifacts/explainer.pkl', 'wb') as f:
    pickle.dump(explainer, f)

# %% [markdown]
# ### Model

# %%
import pickle

with open('../artifacts/model.pkl', 'wb') as f:
    pickle.dump(model, f)
